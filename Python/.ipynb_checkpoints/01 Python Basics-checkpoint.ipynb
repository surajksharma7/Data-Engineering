# %% [markdown]
# ### Why Python
# - Design Philosophy
# - batteries included
# - General Purpose
# - Libraries/ Community

# %% [markdown]
# #### Why Python for Data Science
# - Easy to Learn
# - Proximity With maths
# - Community

# %% [markdown]
# #### Python Outputs

# %%
print("Hello world") # python is a case sensitive language means Python and python are different
# Out:
# Hello world

# %%
print('Hello', 1, 4.5, True, sep='/')
# Out:
# Hello/1/4.5/True

# %% [markdown]
# #### Data Types

# %%
# integer 
print(8)
# Out:
# 8

# %%
# float 
print(8.99)
# Out:
# 8.99

# %%
# Boolean 
print(True)
# Out:
# True

# %%
# string 
print("hello world")
# Out:
# hello world

# %%
# complex number 
print(6+7j)
# Out:
# (6+7j)

# %%
# list 
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# sets 
print({1,2,3,4,5,3})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary 
print({'name':'suraj', 'age':18})
# Out:
# {'name': 'suraj', 'age': 18}

# %%
# type function in python 
type("hello")
# Out:
# str

# %% [markdown]
# #### Variables

# %%
# static vs Dynamic typing 
# static vs dynamic binding 
# Stylish Declaration techniques
a, b = 6,5
a=b=5

# %% [markdown]
# #### User Input

# %%
name = input("Enter your name ")
print(name)
# Out:
# Enter your name  suraj
# suraj

# %%
a = None
print(a)
# Out:
# None
